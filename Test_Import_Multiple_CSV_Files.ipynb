# %% [markdown]
# <a href="https://colab.research.google.com/github/zhangwiki86-soton/L7---Data-Analysis-and-Visualisation/blob/main/Test_Import_Multiple_CSV_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
import glob

# %%
#File path
all_files= glob.glob("C:/Users/ZhangY/Desktop/Workforce/Training Certificates/Apprenticeship/Exeter/Offer/Study Progress/1 Data visualisation COMM035DA/Assessment/West Midlands Police/2024-04/*.csv")
all_files
# Out:
# []

# %%
ListOne=[pd.read_csv(filename, index_col=None, header=0) for filename in all_files]
df=pd.concat(ListOne, axis=0, ignore_index=True)
df.head()

# %% [markdown]
# #some other codes to test
# import dask.dataframe as dd
# ddf = dd.read_csv(
#     'data-*.csv'
# )
# df = ddf.compute()
