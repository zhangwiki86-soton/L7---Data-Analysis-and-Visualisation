# %% [markdown]
# <a href="https://colab.research.google.com/github/zhangwiki86-soton/L7---Data-Analysis-and-Visualisation/blob/main/Git%20clone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zhangwiki86-soton/L7---Data-Analysis-and-Visualisation.git
# Out:
# Cloning into 'L7---Data-Analysis-and-Visualisation'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 42 (delta 22), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 6.84 MiB | 5.26 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# !pip install geopandas

# %%
import pandas as pd
import geopandas as gpd

# %%
data ='/content/L7---Data-Analysis-and-Visualisation/*.csv'
read=pd.read_csv(data)
read
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-853309315.py in <cell line: 0>()
#       1 data ='/content/L7---Data-Analysis-and-Visualisation/*.csv'
# ----> 2 read=pd.read_csv(data)
#       3 read
#
# ...
