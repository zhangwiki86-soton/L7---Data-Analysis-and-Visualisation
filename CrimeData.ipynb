# %% [markdown]
# <a href="https://colab.research.google.com/github/zhangwiki86-soton/L7---Data-Analysis-and-Visualisation/blob/main/CrimeData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crime Data Analysis of WMP

# %% [markdown]
# #1. Importing Libriaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #2. Import Data

# %%
CrimeData=pd.read_csv('https://github.com/zhangwiki86-soton/L7---Data-Analysis-and-Visualisation/blob/main/2023-12-west-midlands-street.csv?raw=true')
CrimeData
# Out:
#                                                 Crime ID    Month  \
# 0      fdbff4da55066884700d48f6ca48e03fbe8a75b6a143cc...  2023-12
# 1      02affdeba7ab5d450fe62e72a2009d0cd796d5aa66f5a2...  2023-12
# 2      9e26f25dc8749749da9e14400236bec7f30872cfe75f9a...  2023-12
# 3      4026edb36cf730ba9ac2b5d7e385d3d20c26fb5c07927c...  2023-12
# 4      452f4613d8c6ca1ba1bdd38b592641bb8d1aafcbf19ea9...  2023-12
# ...                                                  ...      ...
# 28053  629ce5e95a89bf032c096076cef93fcffb906e3d368891...  2023-12
# 28054  ec6985a3b3eab5230828972c4ac594890dd9b7facc6509...  2023-12
# 28055  dd3213d01939c41ff5f3f2353ea6c20937c820bc9007b1...  2023-12
# 28056  bb58815c89bf8e7382f852daf631f2a92a5c961432eb8e...  2023-12
# 28057  442ad91c7d0baa110aae672059cdaeffc7e3f46e2ae6df...  2023-12
#
#                 Reported by          Falls within  Longitude   Latitude  \
# 0      West Midlands Police  West Midlands Police  -1.849790  52.590937
# 1      West Midlands Police  West Midlands Police  -1.849790  52.590937
# 2      West Midlands Police  West Midlands Police  -1.847123  52.593864
# 3      West Midlands Police  West Midlands Police  -1.849790  52.590937
# 4      West Midlands Police  West Midlands Police  -1.849790  52.590937
# ...                     ...                   ...        ...        ...
# 28053  West Midlands Police  West Midlands Police  -2.119472  52.572273
# 28054  West Midlands Police  West Midlands Police  -2.117079  52.571358
# 28055  West Midlands Police  West Midlands Police  -2.118019  52.569505
# 28056  West Midlands Police  West Midlands Police  -2.117890  52.570935
# 28057  West Midlands Police  West Midlands Police  -2.119472  52.572273
#
#                            Location  LSOA code           LSOA name  \
# 0           On or near Walsall Road  E01009417     Birmingham 001A
# 1           On or near Walsall Road  E01009417     Birmingham 001A
# 2            On or near Bramble Way  E01009417     Birmingham 001A
# 3           On or near Walsall Road  E01009417     Birmingham 001A
# 4           On or near Walsall Road  E01009417     Birmingham 001A
# ...                             ...        ...                 ...
# 28053  On or near Silver Birch Road  E01034315  Wolverhampton 035J
# 28054      On or near Willcock Road  E01034315  Wolverhampton 035J
# 28055    On or near Thompson Avenue  E01034315  Wolverhampton 035J
# 28056   On or near Rowan Tree Drive  E01034315  Wolverhampton 035J
# 28057  On or near Silver Birch Road  E01034315  Wolverhampton 035J
#
#                          Crime type  \
# 0                      Public order
# 1             Theft from the person
# 2                     Vehicle crime
# 3      Violence and sexual offences
# 4      Violence and sexual offences
# ...                             ...
# 28053  Violence and sexual offences
# 28054  Violence and sexual offences
# 28055  Violence and sexual offences
# 28056  Violence and sexual offences
# 28057                   Other crime
#
#                                Last outcome category  Context
# 0                        Unable to prosecute suspect      NaN
# 1      Investigation complete; no suspect identified      NaN
# 2      Investigation complete; no suspect identified      NaN
# 3                        Unable to prosecute suspect      NaN
# 4      Investigation complete; no suspect identified      NaN
# ...                                              ...      ...
# 28053                    Unable to prosecute suspect      NaN
# 28054                    Unable to prosecute suspect      NaN
# 28055                    Unable to prosecute suspect      NaN
# 28056                    Unable to prosecute suspect      NaN
# 28057                    Unable to prosecute suspect      NaN
#
# [28058 rows x 12 columns]

# %% [markdown]
# #Structure and Shape

# %%
CrimeData.shape # Dimentions of the DataFrame (number of rows and columns)
# Out:
# (28058, 12)

# %%
CrimeData.index #
#CrimeData.index.to_list()
# Out:
# RangeIndex(start=0, stop=28058, step=1)

# %%
print("colomns:\n", CrimeData.columns) # Column names of the DataFrame
print("colomns:\n", CrimeData.columns.to_list()) # In list
# Out:
# colomns:
#  Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'],
#       dtype='object')
# colomns:
#  ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']

# %%
CrimeData.info()
# number of rows/records
# any null values in each colum, how complete the columns are populated in the data set
# what are the types of attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28058 entries, 0 to 28057
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               26442 non-null  object
#  1   Month                  28058 non-null  object
#  2   Reported by            28058 non-null  object
#  3   Falls within           28058 non-null  object
#  4   Longitude              28058 non-null  float64
#  5   Latitude               28058 non-null  float64
#  6   Location               28058 non-null  object
#  7   LSOA code              28058 non-null  object
#  8   LSOA name              28058 non-null  object
#  9   Crime type             28058 non-null  object
#  10  Last outcome category  26442 non-null  object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 2.6+ MB

# %% [markdown]
# #Content

# %%
CrimeData.head()
CrimeData.tail()
# Out:
#                                                 Crime ID    Month  \
# 28053  629ce5e95a89bf032c096076cef93fcffb906e3d368891...  2023-12
# 28054  ec6985a3b3eab5230828972c4ac594890dd9b7facc6509...  2023-12
# 28055  dd3213d01939c41ff5f3f2353ea6c20937c820bc9007b1...  2023-12
# 28056  bb58815c89bf8e7382f852daf631f2a92a5c961432eb8e...  2023-12
# 28057  442ad91c7d0baa110aae672059cdaeffc7e3f46e2ae6df...  2023-12
#
#                 Reported by          Falls within  Longitude   Latitude  \
# 28053  West Midlands Police  West Midlands Police  -2.119472  52.572273
# 28054  West Midlands Police  West Midlands Police  -2.117079  52.571358
# 28055  West Midlands Police  West Midlands Police  -2.118019  52.569505
# 28056  West Midlands Police  West Midlands Police  -2.117890  52.570935
# 28057  West Midlands Police  West Midlands Police  -2.119472  52.572273
#
#                            Location  LSOA code           LSOA name  \
# 28053  On or near Silver Birch Road  E01034315  Wolverhampton 035J
# 28054      On or near Willcock Road  E01034315  Wolverhampton 035J
# 28055    On or near Thompson Avenue  E01034315  Wolverhampton 035J
# 28056   On or near Rowan Tree Drive  E01034315  Wolverhampton 035J
# 28057  On or near Silver Birch Road  E01034315  Wolverhampton 035J
#
#                          Crime type        Last outcome category  Context
# 28053  Violence and sexual offences  Unable to prosecute suspect      NaN
# 28054  Violence and sexual offences  Unable to prosecute suspect      NaN
# 28055  Violence and sexual offences  Unable to prosecute suspect      NaN
# 28056  Violence and sexual offences  Unable to prosecute suspect      NaN
# 28057                   Other crime  Unable to prosecute suspect      NaN

# %% [markdown]
# #Detecting missing values

# %%
CrimeData.isna()
CrimeData.isnull()
CrimeData.isna().sum()
CrimeData.isnull().sum()
# Out:
# Crime ID                  1616
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                    0
# Latitude                     0
# Location                     0
# LSOA code                    0
# LSOA name                    0
# Crime type                   0
# Last outcome category     1616
# Context                  28058
# dtype: int64

# %% [markdown]
# #Selecting part of the DataFrame or Drop parts not needed

# %%
CleanData=CrimeData.loc[:, ['Month', 'Reported by','Location','LSOA code','LSOA name','Crime type','Last outcome category']]#select Columns needed
CleanData
# Out:
#          Month           Reported by                      Location  LSOA code  \
# 0      2023-12  West Midlands Police       On or near Walsall Road  E01009417
# 1      2023-12  West Midlands Police       On or near Walsall Road  E01009417
# 2      2023-12  West Midlands Police        On or near Bramble Way  E01009417
# 3      2023-12  West Midlands Police       On or near Walsall Road  E01009417
# 4      2023-12  West Midlands Police       On or near Walsall Road  E01009417
# ...        ...                   ...                           ...        ...
# 28053  2023-12  West Midlands Police  On or near Silver Birch Road  E01034315
# 28054  2023-12  West Midlands Police      On or near Willcock Road  E01034315
# 28055  2023-12  West Midlands Police    On or near Thompson Avenue  E01034315
# 28056  2023-12  West Midlands Police   On or near Rowan Tree Drive  E01034315
# 28057  2023-12  West Midlands Police  On or near Silver Birch Road  E01034315
#
#                 LSOA name                    Crime type  \
# 0         Birmingham 001A                  Public order
# 1         Birmingham 001A         Theft from the person
# 2         Birmingham 001A                 Vehicle crime
# 3         Birmingham 001A  Violence and sexual offences
# 4         Birmingham 001A  Violence and sexual offences
# ...                   ...                           ...
# 28053  Wolverhampton 035J  Violence and sexual offences
# 28054  Wolverhampton 035J  Violence and sexual offences
# 28055  Wolverhampton 035J  Violence and sexual offences
# 28056  Wolverhampton 035J  Violence and sexual offences
# 28057  Wolverhampton 035J                   Other crime
#
#                                Last outcome category
# 0                        Unable to prosecute suspect
# 1      Investigation complete; no suspect identified
# 2      Investigation complete; no suspect identified
# 3                        Unable to prosecute suspect
# 4      Investigation complete; no suspect identified
# ...                                              ...
# 28053                    Unable to prosecute suspect
# 28054                    Unable to prosecute suspect
# 28055                    Unable to prosecute suspect
# 28056                    Unable to prosecute suspect
# 28057                    Unable to prosecute suspect
#
# [28058 rows x 7 columns]

# %% [markdown]
# #Missing Data

# %%
CleanData.fillna('No Data', inplace=True)

#CrimeData['Last outcome category'].value_counts()

# %%
CleanData.info() # check if fillna worked
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28058 entries, 0 to 28057
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Month                  28058 non-null  object
#  1   Reported by            28058 non-null  object
#  2   Location               28058 non-null  object
#  3   LSOA code              28058 non-null  object
#  4   LSOA name              28058 non-null  object
#  5   Crime type             28058 non-null  object
#  6   Last outcome category  28058 non-null  object
# dtypes: object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# #Count number of Crims by category

# %%
CleanData['Crime type'].value_counts()
CleanData['Last outcome category'].value_counts()
# Out:
# Last outcome category
# Unable to prosecute suspect                            13754
# Investigation complete; no suspect identified           9751
# No Data                                                 1616
# Court result unavailable                                1492
# Local resolution                                         528
# Action to be taken by another organisation               464
# Offender given a caution                                 194
# Status update unavailable                                138
# Awaiting court outcome                                    47
# Further action is not in the public interest              44
# Formal action is not in the public interest               12
# Further investigation is not in the public interest       11
# Suspect charged as part of another case                    7
# Name: count, dtype: int64
